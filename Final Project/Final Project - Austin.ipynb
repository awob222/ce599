# %% [markdown]
# ## The Safety Implications of the Transition to Connected and Autonomous Vehicles

# %%
import csv
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.font_manager as fm

# %%
av = pd.read_csv('2016Crash.csv', encoding='utf-8', index_col='MasterFile')

# %%
av.head()
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71823466               2       20160806           1529                    0
# 71907155               2       20161128           1355                    0
# 71772302               2       20160511            158                    0
#
#             IntersectionWith_Indicator_  NumberInjured  ofUnits  \
# MasterFile
# 71768481                              0              1        2
# 71813733                              1              1        1
# 71823466                              0              1        2
# 71907155                              1              1        2
# 71772302                              0              1        1
#
#             ofMotorVehicleUnits  SpeedLimitNumber  LatitudeDecimalNumber  \
# MasterFile
# ...

# %% [markdown]
# #### This workbook will display multiple comparisons between the number of people killed in 2016 and different types of statistics that connected and autonomous vehicles can prevent. These lives are treated as saved under the conditions for this project.

# %%
av
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71823466               2       20160806           1529                    0
# 71907155               2       20161128           1355                    0
# 71772302               2       20160511            158                    0
# 71917687               2       20161217           1030                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71728484               2       20160120           1238                    0
# 71743409               2       20160303           1847                    0
# 71874902               2       20161022           2215                    0
# ...

# %% [markdown]
# #### There were 72,726 accident records in the 2016 report. So I filtered out all accidents without death because that is what I am basing this study on. This gave me 480 accidents with at least one death as a result.

# %%
av1 = av[av['NumberKilled']>0]
av1
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71823466               2       20160806           1529                    0
# 71907155               2       20161128           1355                    0
# 71772302               2       20160511            158                    0
# 71917687               2       20161217           1030                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71728484               2       20160120           1238                    0
# 71743409               2       20160303           1847                    0
# 71874902               2       20161022           2215                    0
# ...

# %%
totalkilled = av['NumberKilled'].sum()
totalkilled
# Out:
# 512

# %% [markdown]
# #### CAVs have not been tested in parking lots yet. There were not any deaths here, so filtering this out did not cause a reaction.

# %%
av2 = av1[av1['ParkingLotIndicator']<1]
av2
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71823466               2       20160806           1529                    0
# 71907155               2       20161128           1355                    0
# 71772302               2       20160511            158                    0
# 71917687               2       20161217           1030                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71728484               2       20160120           1238                    0
# 71743409               2       20160303           1847                    0
# 71874902               2       20161022           2215                    0
# ...

# %%
totalsaved_afterparking= av2['NumberKilled'].sum()
totalsaved_afterparking
# Out:
# 512

# %% [markdown]
# #### Next, I checked the weather code on the Kentucky State Police weather code section. CAVs do not work in rainy or snowy weather, which means that all weather codes over 05 must be filtered out, as they will not save lives.

# %%
av3 = av2[av2['WeatherCode']<6]
av3
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71917687               2       20161217           1030                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71728484               2       20160120           1238                    0
# 71743409               2       20160303           1847                    0
# 71874902               2       20161022           2215                    0
# 71765522               2       20160425           1041                    0
# 71760010               2       20160408           1407                    0
# 71786152               2       20160611           1510                    0
# ...

# %%
totalsaved_afterweather= av3['NumberKilled'].sum()
totalsaved_afterweather
# Out:
# 463

# %% [markdown]
# #### The roadway surface code is important. Surface 01 and 02 are asphalt and concrete respectively. Anything else, such as gravel, will not be appropriate for autonomous vehicles today. Therefore, a code 03 and above was eliminated. There was only one in 2016.

# %%
av4 = av3[av3['RoadwaySurfaceCode']<3]
av4
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71917687               2       20161217           1030                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71728484               2       20160120           1238                    0
# 71743409               2       20160303           1847                    0
# 71874902               2       20161022           2215                    0
# 71765522               2       20160425           1041                    0
# 71760010               2       20160408           1407                    0
# 71786152               2       20160611           1510                    0
# ...

# %%
totalsaved_aftersurface = av4['NumberKilled'].sum()
totalsaved_aftersurface
# Out:
# 462

# %% [markdown]
# #### Roadway Condition Code is similar to weather, but it would be after weather is over. CAVs are not ready for snow or other materials on the road, so having snow or rain would require a human driver with the technology today. Codes with a 02 or higher were removed in this case, leaving 388 records.

# %%
av5 = av4[av4['RoadwayConditionCode']<2]
av5
# Out:
#             NumberKilled  CollisionDate  CollisionTime  ParkingLotIndicator  \
# MasterFile
# 71768481               4       20160423           1203                    0
# 71813733               3       20160721            410                    0
# 71752501               2       20160321            610                    0
# 71788145               2       20160604            730                    0
# 71874902               2       20161022           2215                    0
# 71765522               2       20160425           1041                    0
# 71760010               2       20160408           1407                    0
# 71786152               2       20160611           1510                    0
# 71863753               2       20161002           1147                    0
# 71790909               2       20160621           2138                    0
# 71836048               2       20160829           1015                    0
# ...

# %% [markdown]
# #### After eliminating all conditions that would cause an accident out of the hands of a connected and autonomous vehicle, there are 388 crashes in which at least one death occurred. 388 crashes included 413 deaths, which means 413 people could have been saved with autonomous technology today.

# %%
totalsaved = av5['NumberKilled'].sum()
totalsaved
# Out:
# 413

# %% [markdown]
# #### Placed all of the possible outcomes onto a new csv file. This allowed me to make bar graphs and pie charts to show the amount of people saved and how they would still die today.

# %%
df = pd.read_csv('Outcomes.csv', encoding='utf-8', index_col='Number of People')
df.head()
# Out:
#                       Outcome
# Number of People
# 1                 Bad Weather
# 2                 Bad Weather
# 3                 Bad Weather
# 4                 Bad Weather
# 5                 Bad Weather

# %%
outcomes = df['Outcome'].value_counts()
outcomes
# Out:
# Saved By CAVs         413
# Bad Weather            49
# Roadway Conditions     49
# Surface Type            1
# Name: Outcome, dtype: int64

# %% [markdown]
# #### According to the statistics given, if CAVs are used under normal conditions and humans only take control under the abnormal conditions, 413 people will be saved, while 99 people will die through bad weather, bad roadway conditions, or abnormal surface types such as gravel. The bar chart below displays how many people would be saved versus the ones who would not make it.

# %%
outcomes.plot(kind='bar')

# %%
# function to produce more beautiful pie charts with matplotlib
def pie_chart(fractions, #values for the wedges
              labels, #labels for the wedges
              title = '', #title of the pie chart
              cm_name = 'Pastel1', #name of the matplotlib colormap to use
              autopct = lambda x: str(round(x, 1)) + '%', #format the value text on each pie wedge
              labeldistance = 1.05, #where to place wedge labels in relation to pie wedges
              shadow = True, #shadow around the pie
              startangle = 90, #rotate 90 degrees to start the top of the data set on the top of the pie
              edgecolor = 'w', #color of pie wedge edges
              width = 8, #width of the figure in inches
              height = 8, #height of the figure in inches
              grouping_threshold = None, #group all wedges below this value into one 'all others' wedge
              grouping_label = None): #what to label the grouped wedge
    
    # if the user passed a threshold value, group all fractions lower than it into one 'misc' pie wedge
    if not grouping_threshold==None:
        
        # if user didn't pass a label, apply a default text
        if grouping_label == None:
            grouping_label = 'Others'

        # select the rows greater than the cut-off value
        row_mask = fractions > grouping_threshold
        meets_threshold = fractions[row_mask]

        # group all other rows below the cut-off value
        all_others = pd.Series(fractions[~row_mask].sum())
        all_others.index = [grouping_label]

        # append the grouped row to the bottom of the rows to display
        fractions = meets_threshold.append(all_others)
        labels = fractions.index
    
    # get the color map then pull 1 color from it for each pie wedge we'll draw
    color_map = cm.get_cmap(cm_name)
    num_of_colors = len(fractions)
    colors = color_map([x/float(num_of_colors) for x in range(num_of_colors)])
    
    # create the figure and an axis to plot on
    fig, ax = plt.subplots(figsize=[width, height])
    
    # plot the pie
    wedges = ax.pie(fractions, 
                    labels = labels, 
                    labeldistance = labeldistance,
                    autopct = autopct,
                    colors = colors,
                    shadow = shadow, 
                    startangle = startangle)
    
    # change the edgecolor for each wedge
    for wedge in wedges[0]:
        wedge.set_edgecolor(edgecolor)
    

    plt.show()

# %%
# test out our function
pie_chart(fractions = outcomes,
          labels = outcomes.index,
          grouping_threshold = 30,
          grouping_label = 'Others')

# %% [markdown]
# #### The pie chart above shows the percentages of people saved by CAVs compared to the 2016 data in Kentucky. If this correlates to the entire country, then approximately 29,000 people will be saved, while the other 7,000 will still be dead. This raises ethical concerns and whether Kentucky is representative of the entire nation, but it also shows that CAV technology, if working properly, will save many lives down the road.
