# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)
# Out:
# 1435

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]])
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     popup=row['name'])
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes
# Out:
#    airline  airline_id source_x source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0      LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0      LEX      4017  CLT    3876         Y      0
# 2       AA        24.0      LEX      4017  DFW    3670         Y      0
# 3       AA        24.0      LEX      4017  ORD    3830         Y      0
# 4       AF       137.0      LEX      4017  ATL    3682         Y      0
# 5       DL      2009.0      LEX      4017  ATL    3682       NaN      0
# 6       DL      2009.0      LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0      LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0      LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0      LEX      4017  MSP    3858         Y      0
# 10      G4        35.0      LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0      LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0      LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0      LEX      4017  SFB    4167       NaN      0
# 14      KL      3090.0      LEX      4017  ATL    3682         Y      0
# 15      UA      5209.0      LEX      4017  IAH    3550         Y      0
# 16      UA      5209.0      LEX      4017  ORD    3830         Y      0
# 17      US      5265.0      LEX      4017  CLT    3876       NaN      0
# 18      US      5265.0      LEX      4017  DFW    3670       NaN      0
# 19      US      5265.0      LEX      4017  ORD    3830         Y      0
#
#       equipment  id_source     ...      iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017     ...            ATL      KATL     33.636700
# 1       CR7 CRJ       4017     ...            CLT      KCLT     35.214001
# 2       ERD ER4       4017     ...            DFW      KDFW     32.896801
# 3       ERD ER4       4017     ...            ORD      KORD     41.978600
# 4       CRJ CR9       4017     ...            ATL      KATL     33.636700
# 5       M88 717       4017     ...            ATL      KATL     33.636700
# 6           CRJ       4017     ...            DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017     ...            DTW      KDTW     42.212399
# 8           ERJ       4017     ...            LGA      KLGA     40.777199
# 9           CRJ       4017     ...            MSP      KMSP     44.882000
# 10          M80       4017     ...            FLL      KFLL     26.072599
# 11          M80       4017     ...            PGD      KPGD     26.920200
# 12          320       4017     ...            PIE      KPIE     27.910200
# 13      M80 320       4017     ...            SFB      KSFB     28.777599
# 14      CR9 CRJ       4017     ...            ATL      KATL     33.636700
# 15          ERJ       4017     ...            IAH      KIAH     29.984400
# 16      ERJ CRJ       4017     ...            ORD      KORD     41.978600
# 17          CR7       4017     ...            CLT      KCLT     35.214001
# 18          ERD       4017     ...            DFW      KDFW     32.896801
# 19      ERD ER4       4017     ...            ORD      KORD     41.978600
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 4      -84.428101          1026           -5.0         A  America/New_York
# 5      -84.428101          1026           -5.0         A  America/New_York
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 14     -84.428101          1026           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
# 16     -87.904800           672           -6.0         A   America/Chicago
# 17     -80.943100           748           -5.0         A  America/New_York
# 18     -97.038002           607           -6.0         A   America/Chicago
# 19     -87.904800           672           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 4     airport  OurAirports
# 5     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 14    airport  OurAirports
# 15    airport  OurAirports
# 16    airport  OurAirports
# 17    airport  OurAirports
# 18    airport  OurAirports
# 19    airport  OurAirports
#
# [20 rows x 37 columns]

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})
lex_routes.head()
# Out:
#   airline  airline_id source source_id dest dest_id codeshare  stops  \
# 0      9E      3976.0    LEX      4017  ATL    3682       NaN      0
# 1      AA        24.0    LEX      4017  CLT    3876         Y      0
# 2      AA        24.0    LEX      4017  DFW    3670         Y      0
# 3      AA        24.0    LEX      4017  ORD    3830         Y      0
# 4      AF       137.0    LEX      4017  ATL    3682         Y      0
#
#   equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0       CRJ       4017    ...     United States       ATL      KATL
# 1   CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2   ERD ER4       4017    ...     United States       DFW      KDFW
# 3   ERD ER4       4017    ...     United States       ORD      KORD
# 4   CRJ CR9       4017    ...     United States       ATL      KATL
#
#   latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0     33.636700     -84.428101           1026           -5.0         A
# 1     35.214001     -80.943100            748           -5.0         A
# 2     32.896801     -97.038002            607           -6.0         A
# 3     41.978600     -87.904800            672           -6.0         A
# 4     33.636700     -84.428101           1026           -5.0         A
#
#             tz_dest type_dest
# 0  America/New_York   airport
# 1  America/New_York   airport
# 2   America/Chicago   airport
# 3   America/Chicago   airport
# 4  America/New_York   airport
#
# [5 rows x 35 columns]

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source_x source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0      LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0      LEX      4017  CLT    3876         Y      0
# 2       AA        24.0      LEX      4017  DFW    3670         Y      0
# 3       AA        24.0      LEX      4017  ORD    3830         Y      0
# 6       DL      2009.0      LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0      LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0      LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0      LEX      4017  MSP    3858         Y      0
# 10      G4        35.0      LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0      LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0      LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0      LEX      4017  SFB    4167       NaN      0
# 15      UA      5209.0      LEX      4017  IAH    3550         Y      0
#
#       equipment  id_source     ...      iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017     ...            ATL      KATL     33.636700
# 1       CR7 CRJ       4017     ...            CLT      KCLT     35.214001
# 2       ERD ER4       4017     ...            DFW      KDFW     32.896801
# 3       ERD ER4       4017     ...            ORD      KORD     41.978600
# 6           CRJ       4017     ...            DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017     ...            DTW      KDTW     42.212399
# 8           ERJ       4017     ...            LGA      KLGA     40.777199
# 9           CRJ       4017     ...            MSP      KMSP     44.882000
# 10          M80       4017     ...            FLL      KFLL     26.072599
# 11          M80       4017     ...            PGD      KPGD     26.920200
# 12          320       4017     ...            PIE      KPIE     27.910200
# 13      M80 320       4017     ...            SFB      KSFB     28.777599
# 15          ERJ       4017     ...            IAH      KIAH     29.984400
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 15    airport  OurAirports
#
# [13 rows x 37 columns]

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
for name, row in lex_routes.iterrows():
    print (name,row)
# Out:
# 0 airline                                                           9E
# airline_id                                                      3976
# source                                                           LEX
# source_id                                                       4017
# dest                                                             ATL
# dest_id                                                         3682
# codeshare                                                        NaN
# stops                                                              0
# equipment                                                        CRJ
# id_source                                                       4017
# name_source                                       Blue Grass Airport
# city_source                                             Lexington KY
# country_source                                         United States
# iata_source                                                      LEX
# icao_source                                                     KLEX
# latitude_source                                              38.0365
# longitude_source                                            -84.6059
# altitude_source                                                  979
# timezone_source                                                   -5
# dst_source                                                         A
# tz_source                                           America/New_York
# type_source                                                  airport
# id_dest                                                         3682
# name_dest           Hartsfield Jackson Atlanta International Airport
# city_dest                                                    Atlanta
# country_dest                                           United States
# iata_dest                                                        ATL
# icao_dest                                                       KATL
# latitude_dest                                                33.6367
# longitude_dest                                              -84.4281
# altitude_dest                                                   1026
# timezone_dest                                                     -5
# dst_dest                                                           A
# tz_dest                                             America/New_York
# type_dest                                                    airport
# Name: 0, dtype: object
# 1 airline                                                  AA
# airline_id                                               24
# source                                                  LEX
# source_id                                              4017
# dest                                                    CLT
# dest_id                                                3876
# codeshare                                                 Y
# stops                                                     0
# equipment                                           CR7 CRJ
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3876
# name_dest           Charlotte Douglas International Airport
# city_dest                                         Charlotte
# country_dest                                  United States
# iata_dest                                               CLT
# icao_dest                                              KCLT
# latitude_dest                                        35.214
# longitude_dest                                     -80.9431
# altitude_dest                                           748
# timezone_dest                                            -5
# dst_dest                                                  A
# tz_dest                                    America/New_York
# type_dest                                           airport
# Name: 1, dtype: object
# 2 airline                                                  AA
# airline_id                                               24
# source                                                  LEX
# source_id                                              4017
# dest                                                    DFW
# dest_id                                                3670
# codeshare                                                 Y
# stops                                                     0
# equipment                                           ERD ER4
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3670
# name_dest           Dallas Fort Worth International Airport
# city_dest                                 Dallas-Fort Worth
# country_dest                                  United States
# iata_dest                                               DFW
# icao_dest                                              KDFW
# latitude_dest                                       32.8968
# longitude_dest                                      -97.038
# altitude_dest                                           607
# timezone_dest                                            -6
# dst_dest                                                  A
# tz_dest                                     America/Chicago
# type_dest                                           airport
# Name: 2, dtype: object
# 3 airline                                               AA
# airline_id                                            24
# source                                               LEX
# source_id                                           4017
# dest                                                 ORD
# dest_id                                             3830
# codeshare                                              Y
# stops                                                  0
# equipment                                        ERD ER4
# id_source                                           4017
# name_source                           Blue Grass Airport
# city_source                                 Lexington KY
# country_source                             United States
# iata_source                                          LEX
# icao_source                                         KLEX
# latitude_source                                  38.0365
# longitude_source                                -84.6059
# altitude_source                                      979
# timezone_source                                       -5
# dst_source                                             A
# tz_source                               America/New_York
# type_source                                      airport
# id_dest                                             3830
# name_dest           Chicago O'Hare International Airport
# city_dest                                        Chicago
# country_dest                               United States
# iata_dest                                            ORD
# icao_dest                                           KORD
# latitude_dest                                    41.9786
# longitude_dest                                  -87.9048
# altitude_dest                                        672
# timezone_dest                                         -6
# dst_dest                                               A
# tz_dest                                  America/Chicago
# type_dest                                        airport
# Name: 3, dtype: object
# 4 airline                                                           AF
# airline_id                                                       137
# source                                                           LEX
# source_id                                                       4017
# dest                                                             ATL
# dest_id                                                         3682
# codeshare                                                          Y
# stops                                                              0
# equipment                                                    CRJ CR9
# id_source                                                       4017
# name_source                                       Blue Grass Airport
# city_source                                             Lexington KY
# country_source                                         United States
# iata_source                                                      LEX
# icao_source                                                     KLEX
# latitude_source                                              38.0365
# longitude_source                                            -84.6059
# altitude_source                                                  979
# timezone_source                                                   -5
# dst_source                                                         A
# tz_source                                           America/New_York
# type_source                                                  airport
# id_dest                                                         3682
# name_dest           Hartsfield Jackson Atlanta International Airport
# city_dest                                                    Atlanta
# country_dest                                           United States
# iata_dest                                                        ATL
# icao_dest                                                       KATL
# latitude_dest                                                33.6367
# longitude_dest                                              -84.4281
# altitude_dest                                                   1026
# timezone_dest                                                     -5
# dst_dest                                                           A
# tz_dest                                             America/New_York
# type_dest                                                    airport
# Name: 4, dtype: object
# 5 airline                                                           DL
# airline_id                                                      2009
# source                                                           LEX
# source_id                                                       4017
# dest                                                             ATL
# dest_id                                                         3682
# codeshare                                                        NaN
# stops                                                              0
# equipment                                                    M88 717
# id_source                                                       4017
# name_source                                       Blue Grass Airport
# city_source                                             Lexington KY
# country_source                                         United States
# iata_source                                                      LEX
# icao_source                                                     KLEX
# latitude_source                                              38.0365
# longitude_source                                            -84.6059
# altitude_source                                                  979
# timezone_source                                                   -5
# dst_source                                                         A
# tz_source                                           America/New_York
# type_source                                                  airport
# id_dest                                                         3682
# name_dest           Hartsfield Jackson Atlanta International Airport
# city_dest                                                    Atlanta
# country_dest                                           United States
# iata_dest                                                        ATL
# icao_dest                                                       KATL
# latitude_dest                                                33.6367
# longitude_dest                                              -84.4281
# altitude_dest                                                   1026
# timezone_dest                                                     -5
# dst_dest                                                           A
# tz_dest                                             America/New_York
# type_dest                                                    airport
# Name: 5, dtype: object
# 6 airline                                                    DL
# airline_id                                               2009
# source                                                    LEX
# source_id                                                4017
# dest                                                      DCA
# dest_id                                                  3520
# codeshare                                                   Y
# stops                                                       0
# equipment                                                 CRJ
# id_source                                                4017
# name_source                                Blue Grass Airport
# city_source                                      Lexington KY
# country_source                                  United States
# iata_source                                               LEX
# icao_source                                              KLEX
# latitude_source                                       38.0365
# longitude_source                                     -84.6059
# altitude_source                                           979
# timezone_source                                            -5
# dst_source                                                  A
# tz_source                                    America/New_York
# type_source                                           airport
# id_dest                                                  3520
# name_dest           Ronald Reagan Washington National Airport
# city_dest                                          Washington
# country_dest                                    United States
# iata_dest                                                 DCA
# icao_dest                                                KDCA
# latitude_dest                                         38.8521
# longitude_dest                                       -77.0377
# altitude_dest                                              15
# timezone_dest                                              -5
# dst_dest                                                    A
# tz_dest                                      America/New_York
# type_dest                                             airport
# Name: 6, dtype: object
# 7 airline                                                    DL
# airline_id                                               2009
# source                                                    LEX
# source_id                                                4017
# dest                                                      DTW
# dest_id                                                  3645
# codeshare                                                   Y
# stops                                                       0
# equipment                                         CR7 CRJ CR9
# id_source                                                4017
# name_source                                Blue Grass Airport
# city_source                                      Lexington KY
# country_source                                  United States
# iata_source                                               LEX
# icao_source                                              KLEX
# latitude_source                                       38.0365
# longitude_source                                     -84.6059
# altitude_source                                           979
# timezone_source                                            -5
# dst_source                                                  A
# tz_source                                    America/New_York
# type_source                                           airport
# id_dest                                                  3645
# name_dest           Detroit Metropolitan Wayne County Airport
# city_dest                                             Detroit
# country_dest                                    United States
# iata_dest                                                 DTW
# icao_dest                                                KDTW
# latitude_dest                                         42.2124
# longitude_dest                                       -83.3534
# altitude_dest                                             645
# timezone_dest                                              -5
# dst_dest                                                    A
# tz_dest                                      America/New_York
# type_dest                                             airport
# Name: 7, dtype: object
# 8 airline                             DL
# airline_id                        2009
# source                             LEX
# source_id                         4017
# dest                               LGA
# dest_id                           3697
# codeshare                          NaN
# stops                                0
# equipment                          ERJ
# id_source                         4017
# name_source         Blue Grass Airport
# city_source               Lexington KY
# country_source           United States
# iata_source                        LEX
# icao_source                       KLEX
# latitude_source                38.0365
# longitude_source              -84.6059
# altitude_source                    979
# timezone_source                     -5
# dst_source                           A
# tz_source             America/New_York
# type_source                    airport
# id_dest                           3697
# name_dest           La Guardia Airport
# city_dest                     New York
# country_dest             United States
# iata_dest                          LGA
# icao_dest                         KLGA
# latitude_dest                  40.7772
# longitude_dest                -73.8726
# altitude_dest                       21
# timezone_dest                       -5
# dst_dest                             A
# tz_dest               America/New_York
# type_dest                      airport
# Name: 8, dtype: object
# 9 airline                                                            DL
# airline_id                                                       2009
# source                                                            LEX
# source_id                                                        4017
# dest                                                              MSP
# dest_id                                                          3858
# codeshare                                                           Y
# stops                                                               0
# equipment                                                         CRJ
# id_source                                                        4017
# name_source                                        Blue Grass Airport
# city_source                                              Lexington KY
# country_source                                          United States
# iata_source                                                       LEX
# icao_source                                                      KLEX
# latitude_source                                               38.0365
# longitude_source                                             -84.6059
# altitude_source                                                   979
# timezone_source                                                    -5
# dst_source                                                          A
# tz_source                                            America/New_York
# type_source                                                   airport
# id_dest                                                          3858
# name_dest           Minneapolis-St Paul International/Wold-Chamber...
# city_dest                                                 Minneapolis
# country_dest                                            United States
# iata_dest                                                         MSP
# icao_dest                                                        KMSP
# latitude_dest                                                  44.882
# longitude_dest                                               -93.2218
# altitude_dest                                                     841
# timezone_dest                                                      -6
# dst_dest                                                            A
# tz_dest                                               America/Chicago
# type_dest                                                     airport
# Name: 9, dtype: object
# 10 airline                                                          G4
# airline_id                                                       35
# source                                                          LEX
# source_id                                                      4017
# dest                                                            FLL
# dest_id                                                        3533
# codeshare                                                       NaN
# stops                                                             0
# equipment                                                       M80
# id_source                                                      4017
# name_source                                      Blue Grass Airport
# city_source                                            Lexington KY
# country_source                                        United States
# iata_source                                                     LEX
# icao_source                                                    KLEX
# latitude_source                                             38.0365
# longitude_source                                           -84.6059
# altitude_source                                                 979
# timezone_source                                                  -5
# dst_source                                                        A
# tz_source                                          America/New_York
# type_source                                                 airport
# id_dest                                                        3533
# name_dest           Fort Lauderdale Hollywood International Airport
# city_dest                                           Fort Lauderdale
# country_dest                                          United States
# iata_dest                                                       FLL
# icao_dest                                                      KFLL
# latitude_dest                                               26.0726
# longitude_dest                                             -80.1527
# altitude_dest                                                     9
# timezone_dest                                                    -5
# dst_dest                                                          A
# tz_dest                                            America/New_York
# type_dest                                                   airport
# Name: 10, dtype: object
# 11 airline                                   G4
# airline_id                                35
# source                                   LEX
# source_id                               4017
# dest                                     PGD
# dest_id                                 7056
# codeshare                                NaN
# stops                                      0
# equipment                                M80
# id_source                               4017
# name_source               Blue Grass Airport
# city_source                     Lexington KY
# country_source                 United States
# iata_source                              LEX
# icao_source                             KLEX
# latitude_source                      38.0365
# longitude_source                    -84.6059
# altitude_source                          979
# timezone_source                           -5
# dst_source                                 A
# tz_source                   America/New_York
# type_source                          airport
# id_dest                                 7056
# name_dest           Charlotte County Airport
# city_dest                        Punta Gorda
# country_dest                   United States
# iata_dest                                PGD
# icao_dest                               KPGD
# latitude_dest                        26.9202
# longitude_dest                      -81.9905
# altitude_dest                             26
# timezone_dest                             -5
# dst_dest                                   A
# tz_dest                     America/New_York
# type_dest                            airport
# Name: 11, dtype: object
# 12 airline                                                         G4
# airline_id                                                      35
# source                                                         LEX
# source_id                                                     4017
# dest                                                           PIE
# dest_id                                                       3617
# codeshare                                                      NaN
# stops                                                            0
# equipment                                                      320
# id_source                                                     4017
# name_source                                     Blue Grass Airport
# city_source                                           Lexington KY
# country_source                                       United States
# iata_source                                                    LEX
# icao_source                                                   KLEX
# latitude_source                                            38.0365
# longitude_source                                          -84.6059
# altitude_source                                                979
# timezone_source                                                 -5
# dst_source                                                       A
# tz_source                                         America/New_York
# type_source                                                airport
# id_dest                                                       3617
# name_dest           St Petersburg Clearwater International Airport
# city_dest                                           St. Petersburg
# country_dest                                         United States
# iata_dest                                                      PIE
# icao_dest                                                     KPIE
# latitude_dest                                              27.9102
# longitude_dest                                            -82.6874
# altitude_dest                                                   11
# timezone_dest                                                   -5
# dst_dest                                                         A
# tz_dest                                           America/New_York
# type_dest                                                  airport
# Name: 12, dtype: object
# 13 airline                                                G4
# airline_id                                             35
# source                                                LEX
# source_id                                            4017
# dest                                                  SFB
# dest_id                                              4167
# codeshare                                             NaN
# stops                                                   0
# equipment                                         M80 320
# id_source                                            4017
# name_source                            Blue Grass Airport
# city_source                                  Lexington KY
# country_source                              United States
# iata_source                                           LEX
# icao_source                                          KLEX
# latitude_source                                   38.0365
# longitude_source                                 -84.6059
# altitude_source                                       979
# timezone_source                                        -5
# dst_source                                              A
# tz_source                                America/New_York
# type_source                                       airport
# id_dest                                              4167
# name_dest           Orlando Sanford International Airport
# city_dest                                         Sanford
# country_dest                                United States
# iata_dest                                             SFB
# icao_dest                                            KSFB
# latitude_dest                                     28.7776
# longitude_dest                                   -81.2375
# altitude_dest                                          55
# timezone_dest                                          -5
# dst_dest                                                A
# tz_dest                                  America/New_York
# type_dest                                         airport
# Name: 13, dtype: object
# 14 airline                                                           KL
# airline_id                                                      3090
# source                                                           LEX
# source_id                                                       4017
# dest                                                             ATL
# dest_id                                                         3682
# codeshare                                                          Y
# stops                                                              0
# equipment                                                    CR9 CRJ
# id_source                                                       4017
# name_source                                       Blue Grass Airport
# city_source                                             Lexington KY
# country_source                                         United States
# iata_source                                                      LEX
# icao_source                                                     KLEX
# latitude_source                                              38.0365
# longitude_source                                            -84.6059
# altitude_source                                                  979
# timezone_source                                                   -5
# dst_source                                                         A
# tz_source                                           America/New_York
# type_source                                                  airport
# id_dest                                                         3682
# name_dest           Hartsfield Jackson Atlanta International Airport
# city_dest                                                    Atlanta
# country_dest                                           United States
# iata_dest                                                        ATL
# icao_dest                                                       KATL
# latitude_dest                                                33.6367
# longitude_dest                                              -84.4281
# altitude_dest                                                   1026
# timezone_dest                                                     -5
# dst_dest                                                           A
# tz_dest                                             America/New_York
# type_dest                                                    airport
# Name: 14, dtype: object
# 15 airline                                                       UA
# airline_id                                                  5209
# source                                                       LEX
# source_id                                                   4017
# dest                                                         IAH
# dest_id                                                     3550
# codeshare                                                      Y
# stops                                                          0
# equipment                                                    ERJ
# id_source                                                   4017
# name_source                                   Blue Grass Airport
# city_source                                         Lexington KY
# country_source                                     United States
# iata_source                                                  LEX
# icao_source                                                 KLEX
# latitude_source                                          38.0365
# longitude_source                                        -84.6059
# altitude_source                                              979
# timezone_source                                               -5
# dst_source                                                     A
# tz_source                                       America/New_York
# type_source                                              airport
# id_dest                                                     3550
# name_dest           George Bush Intercontinental Houston Airport
# city_dest                                                Houston
# country_dest                                       United States
# iata_dest                                                    IAH
# icao_dest                                                   KIAH
# latitude_dest                                            29.9844
# longitude_dest                                          -95.3414
# altitude_dest                                                 97
# timezone_dest                                                 -6
# dst_dest                                                       A
# tz_dest                                          America/Chicago
# type_dest                                                airport
# Name: 15, dtype: object
# 16 airline                                               UA
# airline_id                                          5209
# source                                               LEX
# source_id                                           4017
# dest                                                 ORD
# dest_id                                             3830
# codeshare                                              Y
# stops                                                  0
# equipment                                        ERJ CRJ
# id_source                                           4017
# name_source                           Blue Grass Airport
# city_source                                 Lexington KY
# country_source                             United States
# iata_source                                          LEX
# icao_source                                         KLEX
# latitude_source                                  38.0365
# longitude_source                                -84.6059
# altitude_source                                      979
# timezone_source                                       -5
# dst_source                                             A
# tz_source                               America/New_York
# type_source                                      airport
# id_dest                                             3830
# name_dest           Chicago O'Hare International Airport
# city_dest                                        Chicago
# country_dest                               United States
# iata_dest                                            ORD
# icao_dest                                           KORD
# latitude_dest                                    41.9786
# longitude_dest                                  -87.9048
# altitude_dest                                        672
# timezone_dest                                         -6
# dst_dest                                               A
# tz_dest                                  America/Chicago
# type_dest                                        airport
# Name: 16, dtype: object
# 17 airline                                                  US
# airline_id                                             5265
# source                                                  LEX
# source_id                                              4017
# dest                                                    CLT
# dest_id                                                3876
# codeshare                                               NaN
# stops                                                     0
# equipment                                               CR7
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3876
# name_dest           Charlotte Douglas International Airport
# city_dest                                         Charlotte
# country_dest                                  United States
# iata_dest                                               CLT
# icao_dest                                              KCLT
# latitude_dest                                        35.214
# longitude_dest                                     -80.9431
# altitude_dest                                           748
# timezone_dest                                            -5
# dst_dest                                                  A
# tz_dest                                    America/New_York
# type_dest                                           airport
# Name: 17, dtype: object
# 18 airline                                                  US
# airline_id                                             5265
# source                                                  LEX
# source_id                                              4017
# dest                                                    DFW
# dest_id                                                3670
# codeshare                                               NaN
# stops                                                     0
# equipment                                               ERD
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3670
# name_dest           Dallas Fort Worth International Airport
# city_dest                                 Dallas-Fort Worth
# country_dest                                  United States
# iata_dest                                               DFW
# icao_dest                                              KDFW
# latitude_dest                                       32.8968
# longitude_dest                                      -97.038
# altitude_dest                                           607
# timezone_dest                                            -6
# dst_dest                                                  A
# tz_dest                                     America/Chicago
# type_dest                                           airport
# Name: 18, dtype: object
# 19 airline                                               US
# airline_id                                          5265
# source                                               LEX
# source_id                                           4017
# dest                                                 ORD
# dest_id                                             3830
# codeshare                                              Y
# stops                                                  0
# equipment                                        ERD ER4
# id_source                                           4017
# name_source                           Blue Grass Airport
# city_source                                 Lexington KY
# country_source                             United States
# iata_source                                          LEX
# icao_source                                         KLEX
# latitude_source                                  38.0365
# longitude_source                                -84.6059
# altitude_source                                      979
# timezone_source                                       -5
# dst_source                                             A
# tz_source                               America/New_York
# type_source                                      airport
# id_dest                                             3830
# name_dest           Chicago O'Hare International Airport
# city_dest                                        Chicago
# country_dest                               United States
# iata_dest                                            ORD
# icao_dest                                           KORD
# latitude_dest                                    41.9786
# longitude_dest                                  -87.9048
# altitude_dest                                        672
# timezone_dest                                         -6
# dst_dest                                               A
# tz_dest                                  America/Chicago
# type_dest                                        airport
# Name: 19, dtype: object

# %%
import pandas as pd
import numpy as np

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bcedc6056aaf> in <module>()
#       1 # any time we write a function, we should test that it works
# ----> 2 p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101)
#       3 p
#
# NameError: name 'getGreatCirclePoints' is not defined

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.
#
# Bonus: This is the air travel version of the Kevin Bacon game (https://oracleofbacon.org/).  What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# Extra Bonus: Use this very important piece of knowledge to impress your friends at parties!

# %%
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')
lex_routes
# Out:
#    airline  airline_id source_x source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX      4017  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX      4017  CLT   3876.0         Y      0
# 2       AA        24.0      LEX      4017  DFW   3670.0         Y      0
# 3       AA        24.0      LEX      4017  ORD   3830.0         Y      0
# 4       AF       137.0      LEX      4017  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX      4017  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX      4017  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX      4017  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX      4017  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX      4017  MSP   3858.0         Y      0
# 10      G4        35.0      LEX      4017  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX      4017  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX      4017  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX      4017  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX      4017  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX      4017  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX      4017  ORD   3830.0         Y      0
# 17      US      5265.0      LEX      4017  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX      4017  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX      4017  ORD   3830.0         Y      0
#
#       equipment    id     ...      iata  icao   latitude  longitude altitude  \
# 0           CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 1       CR7 CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 2       ERD ER4  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 3       ERD ER4  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 4       CRJ CR9  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 5       M88 717  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 6           CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 7   CR7 CRJ CR9  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 8           ERJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 9           CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 10          M80  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 11          M80  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 12          320  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 13      M80 320  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 14      CR9 CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 15          ERJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 16      ERJ CRJ  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 17          CR7  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 18          ERD  4017     ...       LEX  KLEX  38.036499 -84.605904      979
# 19      ERD ER4  4017     ...       LEX  KLEX  38.036499 -84.605904      979
#
#     timezone  dst                tz     type     source_y
# 0       -5.0    A  America/New_York  airport  OurAirports
# 1       -5.0    A  America/New_York  airport  OurAirports
# 2       -5.0    A  America/New_York  airport  OurAirports
# 3       -5.0    A  America/New_York  airport  OurAirports
# 4       -5.0    A  America/New_York  airport  OurAirports
# 5       -5.0    A  America/New_York  airport  OurAirports
# 6       -5.0    A  America/New_York  airport  OurAirports
# 7       -5.0    A  America/New_York  airport  OurAirports
# 8       -5.0    A  America/New_York  airport  OurAirports
# 9       -5.0    A  America/New_York  airport  OurAirports
# 10      -5.0    A  America/New_York  airport  OurAirports
# 11      -5.0    A  America/New_York  airport  OurAirports
# 12      -5.0    A  America/New_York  airport  OurAirports
# 13      -5.0    A  America/New_York  airport  OurAirports
# 14      -5.0    A  America/New_York  airport  OurAirports
# 15      -5.0    A  America/New_York  airport  OurAirports
# 16      -5.0    A  America/New_York  airport  OurAirports
# 17      -5.0    A  America/New_York  airport  OurAirports
# 18      -5.0    A  America/New_York  airport  OurAirports
# 19      -5.0    A  America/New_York  airport  OurAirports
#
# [20 rows x 23 columns]

# %%
LEX = list(lex_routes.dest)
LEX[0]
# Out:
# 'ATL'

# %%
LEX1 = str(l[0])
df1 = routes[(routes['source'] == LEX1)]

# %%
lexroutes = pd.DataFrame(columns=['airline', 'airline_id', 'source', 'source_id', 'dest', 'dest_id', 'codeshare', 'stops', 'equipment'])
for i in range(len(LEX)):
    lexingtonroutes = routes[(routes['source']==str(LEX[i]))]
    lexroutes = routes1.append(lexingtonroutes)

# %%
lexroutes.head()
# Out:
#      airline  airline_id source  source_id dest  dest_id codeshare stops  \
# 265       3E     10739.0    ORD     3830.0  BRL   5726.0       NaN     0
# 266       3E     10739.0    ORD     3830.0  DEC   4042.0       NaN     0
# 6226      AA        24.0    ORD     3830.0  ABQ   4019.0         Y     0
# 6227      AA        24.0    ORD     3830.0  ALO   5718.0         Y     0
# 6228      AA        24.0    ORD     3830.0  AMM   2170.0         Y     0
#
#      equipment
# 265        CNC
# 266        CNC
# 6226       E75
# 6227       ERD
# 6228       340

# %%
transfer1 = lexroutes.dest.drop_duplicates()
t = list(transfer1)
t
# Out:
# ['BRL',
#  'DEC',
#  'ABQ',
#  'ALO',
#  'AMM',
#  'ART',
#  'ATL',
#  'AUH',
#  'AUS',
#  'AZO',
#  'BDL',
#  'BMI',
#  'BNA',
#  'BOS',
#  'BUF',
#  'BWI',
#  'CDG',
#  'CHA',
#  'CHO',
#  'CID',
#  'CLE',
#  'CLT',
#  'CMH',
#  'CMI',
#  'COU',
#  'CUN',
#  'CVG',
#  'CWA',
#  'DAY',
#  'DBQ',
#  'DCA',
#  'DEN',
#  'DFW',
#  'DOH',
#  'DSM',
#  'DTW',
#  'DUB',
#  'DUS',
#  'ELP',
#  'EVV',
#  'EWR',
#  'FAR',
#  'FCO',
#  'FLL',
#  'FNT',
#  'FSD',
#  'FWA',
#  'GRB',
#  'GRR',
#  'HKG',
#  'HPN',
#  'HSV',
#  'IAH',
#  'ICT',
#  'IND',
#  'JAX',
#  'JFK',
#  'LAS',
#  'LAX',
#  'LEX',
#  'LGA',
#  'LHR',
#  'LIT',
#  'LSE',
#  'MAD',
#  'MAN',
#  'MBJ',
#  'MCI',
#  'MCO',
#  'MDT',
#  'MEM',
#  'MEX',
#  'MHK',
#  'MIA',
#  'MKE',
#  'MLI',
#  'MQT',
#  'MSN',
#  'MSP',
#  'MSY',
#  'NRT',
#  'OKC',
#  'OMA',
#  'PBI',
#  'PDX',
#  'PEK',
#  'PHL',
#  'PHX',
#  'PIA',
#  'PIT',
#  'PSP',
#  'PVG',
#  'PVR',
#  'RDU',
#  'RIC',
#  'RNO',
#  'ROC',
#  'RST',
#  'RSW',
#  'SAN',
#  'SAT',
#  'SDF',
#  'SEA',
#  'SFO',
#  'SGF',
#  'SJC',
#  'SJD',
#  'SJU',
#  'SLC',
#  'SNA',
#  'STL',
#  'SUX',
#  'SYR',
#  'TOL',
#  'TPA',
#  'TUL',
#  'TUS',
#  'TVC',
#  'TXL',
#  'TYS',
#  'XNA',
#  'YKF',
#  'YUL',
#  'YVR',
#  'YYC',
#  'YYZ',
#  'YEG',
#  'YHZ',
#  'YOW',
#  'YQB',
#  'YQR',
#  'YWG',
#  'YXU',
#  'DEL',
#  'GDL',
#  'ANC',
#  'SAL',
#  'PTY',
#  'AMS',
#  'ICN',
#  'PUJ',
#  'GCM',
#  'FRA',
#  'MUC',
#  'WAW',
#  'ZRH',
#  'ACY',
#  'MYR',
#  'OAK',
#  'VIE',
#  'ARN',
#  'CPH',
#  'BRU',
#  'IST',
#  'ABE',
#  'ALB',
#  'ATW',
#  'AVL',
#  'AVP',
#  'BHM',
#  'BOI',
#  'BTV',
#  'BZN',
#  'CAE',
#  'CAK',
#  'CHS',
#  'CMX',
#  'COS',
#  'CRW',
#  'DLH',
#  'EAU',
#  'ELM',
#  'FOE',
#  'GRU',
#  'GSO',
#  'GSP',
#  'HNL',
#  'IAD',
#  'JAN',
#  'LAN',
#  'LNK',
#  'MBS',
#  'MHT',
#  'MKG',
#  'MOB',
#  'MTY',
#  'NAS',
#  'OGG',
#  'ORF',
#  'PAH',
#  'PNS',
#  'PVD',
#  'PWM',
#  'RAP',
#  'ROA',
#  'SAV',
#  'SBN',
#  'SCE',
#  'SJO',
#  'SMF',
#  'SPI',
#  'SRQ',
#  'STC',
#  'STT',
#  'SXM',
#  'YXE']

# %%
lexroutes2 = pd.DataFrame(columns=['airline', 'airline_id', 'source', 'source_id', 'dest', 'dest_id', 'codeshare', 'stops', 'equipment'])
for i in range (len(t)):
    lexingtonroutes = routes[(routes['source'] == str(t[i]))]
    lexroutes2 = routes2.append(lexingtonroutes)
transfer2 = lexroutes2.dest.drop_duplicates()
transfer2
# Out:
# 474      ATL
# 57070    IAD
# 476      MCO
# 509      GLH
# 4729     ORD
# 20286    DTW
# 20287    MSP
# 4865     CLT
# 4866     DCA
# 4867     DFW
# 28919    PIE
# 28920    SFB
# 24330    DEN
# 28921    AZA
# 28922    LAS
# 28923    PGD
# 43352    MYR
# 5058     JFK
# 5059     MIA
# 5061     PHL
# 7862     YYZ
# 9450     CDG
# 10951    CUN
# 20479    BDL
# 20480    BNA
# 20481    BOS
# 20482    BWI
# 20490    EWR
# 20491    FLL
# 20492    GRR
#         ...
# 48531    NSK
# 48532    NUX
# 48533    NYM
# 48535    OGZ
# 48539    PEE
# 48542    PWQ
# 48543    RGK
# 48546    SGC
# 48547    SIP
# 48549    STW
# 48553    TJM
# 48555    TOF
# 48558    UKK
# 55529    GBB
# 55539    LLK
# 55540    LWN
# 55547    RMI
# 58142    BQS
# 58147    DYR
# 58149    GDX
# 58154    HMA
# 58157    IEV
# 58160    KGF
# 58162    KOV
# 58175    PED
# 58178    PKC
# 61436    CXR
# 66027    NOJ
# 66030    SLY
# 66318    UKS
# Name: dest, Length: 1853, dtype: object

# %%
LEX.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-fc1a2b28f6a5> in <module>()
# ----> 1 LEX.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
kentucky = list(transfer1)
kentucky
# Out:
# ['BRL',
#  'DEC',
#  'ABQ',
#  'ALO',
#  'AMM',
#  'ART',
#  'ATL',
#  'AUH',
#  'AUS',
#  'AZO',
#  'BDL',
#  'BMI',
#  'BNA',
#  'BOS',
#  'BUF',
#  'BWI',
#  'CDG',
#  'CHA',
#  'CHO',
#  'CID',
#  'CLE',
#  'CLT',
#  'CMH',
#  'CMI',
#  'COU',
#  'CUN',
#  'CVG',
#  'CWA',
#  'DAY',
#  'DBQ',
#  'DCA',
#  'DEN',
#  'DFW',
#  'DOH',
#  'DSM',
#  'DTW',
#  'DUB',
#  'DUS',
#  'ELP',
#  'EVV',
#  'EWR',
#  'FAR',
#  'FCO',
#  'FLL',
#  'FNT',
#  'FSD',
#  'FWA',
#  'GRB',
#  'GRR',
#  'HKG',
#  'HPN',
#  'HSV',
#  'IAH',
#  'ICT',
#  'IND',
#  'JAX',
#  'JFK',
#  'LAS',
#  'LAX',
#  'LEX',
#  'LGA',
#  'LHR',
#  'LIT',
#  'LSE',
#  'MAD',
#  'MAN',
#  'MBJ',
#  'MCI',
#  'MCO',
#  'MDT',
#  'MEM',
#  'MEX',
#  'MHK',
#  'MIA',
#  'MKE',
#  'MLI',
#  'MQT',
#  'MSN',
#  'MSP',
#  'MSY',
#  'NRT',
#  'OKC',
#  'OMA',
#  'PBI',
#  'PDX',
#  'PEK',
#  'PHL',
#  'PHX',
#  'PIA',
#  'PIT',
#  'PSP',
#  'PVG',
#  'PVR',
#  'RDU',
#  'RIC',
#  'RNO',
#  'ROC',
#  'RST',
#  'RSW',
#  'SAN',
#  'SAT',
#  'SDF',
#  'SEA',
#  'SFO',
#  'SGF',
#  'SJC',
#  'SJD',
#  'SJU',
#  'SLC',
#  'SNA',
#  'STL',
#  'SUX',
#  'SYR',
#  'TOL',
#  'TPA',
#  'TUL',
#  'TUS',
#  'TVC',
#  'TXL',
#  'TYS',
#  'XNA',
#  'YKF',
#  'YUL',
#  'YVR',
#  'YYC',
#  'YYZ',
#  'YEG',
#  'YHZ',
#  'YOW',
#  'YQB',
#  'YQR',
#  'YWG',
#  'YXU',
#  'DEL',
#  'GDL',
#  'ANC',
#  'SAL',
#  'PTY',
#  'AMS',
#  'ICN',
#  'PUJ',
#  'GCM',
#  'FRA',
#  'MUC',
#  'WAW',
#  'ZRH',
#  'ACY',
#  'MYR',
#  'OAK',
#  'VIE',
#  'ARN',
#  'CPH',
#  'BRU',
#  'IST',
#  'ABE',
#  'ALB',
#  'ATW',
#  'AVL',
#  'AVP',
#  'BHM',
#  'BOI',
#  'BTV',
#  'BZN',
#  'CAE',
#  'CAK',
#  'CHS',
#  'CMX',
#  'COS',
#  'CRW',
#  'DLH',
#  'EAU',
#  'ELM',
#  'FOE',
#  'GRU',
#  'GSO',
#  'GSP',
#  'HNL',
#  'IAD',
#  'JAN',
#  'LAN',
#  'LNK',
#  'MBS',
#  'MHT',
#  'MKG',
#  'MOB',
#  'MTY',
#  'NAS',
#  'OGG',
#  'ORF',
#  'PAH',
#  'PNS',
#  'PVD',
#  'PWM',
#  'RAP',
#  'ROA',
#  'SAV',
#  'SBN',
#  'SCE',
#  'SJO',
#  'SMF',
#  'SPI',
#  'SRQ',
#  'STC',
#  'STT',
#  'SXM',
#  'YXE']

# %%
routecombination = pd.DataFrame(columns=['id', 'name', 'city', 'country', 'iata', 'icao', 'latitude', 'longitude', 'altitude','timezone', 'dst', 'tz', 'type', 'source'])
for i in range(len(kentucky)):
    lexingtonroutes = airports[(airports['iata']==str(kentucky[i]))]
    routecombination = routecombination.append(lexingtonroutes)
routecombination
# Out:
#         id                                               name  \
# 4392  5726                    Southeast Iowa Regional Airport
# 3804  4042                                    Decatur Airport
# 3784  4019          Albuquerque International Sunport Airport
# 4384  5718                          Waterloo Regional Airport
# 2083  2170                   Queen Alia International Airport
# 3619  3838                    Watertown International Airport
# 3467  3682   Hartsfield Jackson Atlanta International Airport
# 2092  2179                    Abu Dhabi International Airport
# 3458  3673             Austin Bergstrom International Airport
# 3801  4039       Kalamazoo Battle Creek International Airport
# 3606  3825                      Bradley International Airport
# 3799  4037  Central Illinois Regional Airport at Bloomingt...
# 3475  3690                    Nashville International Airport
# 3236  3448  General Edward Lawrence Logan International Ai...
# 3601  3820              Buffalo Niagara International Airport
# 3629  3849  Baltimore/Washington International Thurgood Ma...
# 1346  1382            Charles de Gaulle International Airport
# 3363  3578                                       Lovell Field
# 3780  4015                  Charlottesville Albemarle Airport
# 3805  4043                           The Eastern Iowa Airport
# 3274  3486            Cleveland Hopkins International Airport
# 3656  3876            Charlotte Douglas International Airport
# 3541  3759                Port Columbus International Airport
# 3811  4049             University of Illinois Willard Airport
# 3503  3719                          Columbia Regional Airport
# 1794  1852                       Cancún International Airport
# 3276  3488  Cincinnati Northern Kentucky International Air...
# 3807  4045                          Central Wisconsin Airport
# 3412  3627           James M Cox Dayton International Airport
# 4089  4388                           Dubuque Regional Airport
# ...    ...                                                ...
# 3511  3728                     Honolulu International Airport
# 3498  3714            Washington Dulles International Airport
# 3365  3580   Jackson-Medgar Wiley Evers International Airport
# 3329  3544                               Capital City Airport
# 3328  3543                                    Lincoln Airport
# 3880  4128                          MBS International Airport
# 3776  4011                                 Manchester Airport
# 4420  5754                            Muskegon County Airport
# 3564  3782                            Mobile Regional Airport
# 1767  1825     General Mariano Escobedo International Airport
# 1887  1953              Lynden Pindling International Airport
# 3244  3456                                    Kahului Airport
# 3396  3611                      Norfolk International Airport
# 3873  4117                           Barkley Regional Airport
# 3349  3564                         Pensacola Regional Airport
# 3426  3641               Theodore Francis Green State Airport
# 3642  3862             Portland International Jetport Airport
# 3843  4087                        Rapid City Regional Airport
# 3781  4016                Roanoke–Blacksburg Regional Airport
# 3398  3613         Savannah Hilton Head International Airport
# 4064  4359                        South Bend Regional Airport
# 4030  4318                            University Park Airport
# 1825  1885              Juan Santamaria International Airport
# 3598  3817                   Sacramento International Airport
# 4043  4336                    Abraham Lincoln Capital Airport
# 3827  4067           Sarasota Bradenton International Airport
# 3993  4271                          St Cloud Regional Airport
# 2736  2883                              Cyril E. King Airport
# 2751  2899             Princess Juliana International Airport
# 164    166  Saskatoon John G. Diefenbaker International Ai...
#
#                             city               country iata  icao   latitude  \
# 4392                  Burlington         United States  BRL  KBRL  40.783199
# 3804                     Decatur         United States  DEC  KDEC  39.834599
# 3784                 Albuquerque         United States  ABQ  KABQ  35.040199
# 4384                    Waterloo         United States  ALO  KALO  42.557098
# 2083                       Amman                Jordan  AMM  OJAI  31.722601
# 3619                   Watertown         United States  ART  KART  43.991901
# 3467                     Atlanta         United States  ATL  KATL  33.636700
# 2092                   Abu Dhabi  United Arab Emirates  AUH  OMAA  24.433001
# 3458                      Austin         United States  AUS  KAUS  30.194500
# 3801                   Kalamazoo         United States  AZO  KAZO  42.234901
# 3606               Windsor Locks         United States  BDL  KBDL  41.938900
# 3799                 Bloomington         United States  BMI  KBMI  40.477100
# 3475                   Nashville         United States  BNA  KBNA  36.124500
# 3236                      Boston         United States  BOS  KBOS  42.364300
# 3601                     Buffalo         United States  BUF  KBUF  42.940498
# 3629                   Baltimore         United States  BWI  KBWI  39.175400
# 1346                       Paris                France  CDG  LFPG  49.012798
# 3363                 Chattanooga         United States  CHA  KCHA  35.035301
# 3780          Charlottesville VA         United States  CHO  KCHO  38.138599
# 3805                Cedar Rapids         United States  CID  KCID  41.884701
# 3274                   Cleveland         United States  CLE  KCLE  41.411701
# 3656                   Charlotte         United States  CLT  KCLT  35.214001
# 3541                    Columbus         United States  CMH  KCMH  39.998001
# 3811                   Champaign         United States  CMI  KCMI  40.039200
# 3503                    Columbia         United States  COU  KCOU  38.818100
# 1794                      Cancun                Mexico  CUN  MMUN  21.036501
# 3276                  Cincinnati         United States  CVG  KCVG  39.048801
# 3807                      Wassau         United States  CWA  KCWA  44.777599
# 3412                      Dayton         United States  DAY  KDAY  39.902401
# 4089                  Dubuque IA         United States  DBQ  KDBQ  42.402000
# ...                          ...                   ...  ...   ...        ...
# 3511                    Honolulu         United States  HNL  PHNL  21.318701
# 3498                  Washington         United States  IAD  KIAD  38.944500
# 3365                     Jackson         United States  JAN  KJAN  32.311199
# 3329                     Lansing         United States  LAN  KLAN  42.778702
# 3328                     Lincoln         United States  LNK  KLNK  40.851002
# 3880                     Saginaw         United States  MBS  KMBS  43.532902
# 3776               Manchester NH         United States  MHT  KMHT  42.932598
# 4420                    Muskegon         United States  MKG  KMKG  43.169498
# 3564                      Mobile         United States  MOB  KMOB  30.691200
# 1767                   Monterrey                Mexico  MTY  MMMY  25.778500
# 1887                      Nassau               Bahamas  NAS  MYNN  25.039000
# 3244                     Kahului         United States  OGG  PHOG  20.898600
# 3396                     Norfolk         United States  ORF  KORF  36.894600
# 3873                     PADUCAH         United States  PAH  KPAH  37.060799
# 3349                   Pensacola         United States  PNS  KPNS  30.473400
# 3426                  Providence         United States  PVD  KPVD  41.732601
# 3642                    Portland         United States  PWM  KPWM  43.646198
# 3843                  Rapid City         United States  RAP  KRAP  44.045300
# 3781                  Roanoke VA         United States  ROA  KROA  37.325500
# 3398                    Savannah         United States  SAV  KSAV  32.127602
# 4064                  South Bend         United States  SBN  KSBN  41.708698
# 4030  State College Pennsylvania         United States  SCE  KUNV  40.849300
# 1825                    San Jose            Costa Rica  SJO  MROC   9.993860
# 3598                  Sacramento         United States  SMF  KSMF  38.695400
# 4043                 Springfield         United States  SPI  KSPI  39.844101
# 3827                    Sarasota         United States  SRQ  KSRQ  27.395399
# 3993                 Saint Cloud         United States  STC  KSTC  45.546600
# 2736                  St. Thomas        Virgin Islands  STT  TIST  18.337299
# 2751                 Philipsburg  Netherlands Antilles  SXM  TNCM  18.041000
# 164                    Saskatoon                Canada  YXE  CYXE  52.170799
#
#        longitude altitude  timezone dst                   tz     type  \
# 4392  -91.125504      698      -6.0   A      America/Chicago  airport
# 3804  -88.865700      682      -6.0   A      America/Chicago  airport
# 3784 -106.609001     5355      -7.0   A       America/Denver  airport
# 4384  -92.400299      873      -6.0   A      America/Chicago  airport
# 2083   35.993198     2395       2.0   E           Asia/Amman  airport
# 3619  -76.021698      325      -5.0   A     America/New_York  airport
# 3467  -84.428101     1026      -5.0   A     America/New_York  airport
# 2092   54.651100       88       4.0   U           Asia/Dubai  airport
# 3458  -97.669899      542      -6.0   A      America/Chicago  airport
# 3801  -85.552101      874      -5.0   A     America/New_York  airport
# 3606  -72.683197      173      -5.0   A     America/New_York  airport
# 3799  -88.915901      871      -6.0   A      America/Chicago  airport
# 3475  -86.678200      599      -6.0   A      America/Chicago  airport
# 3236  -71.005203       20      -5.0   A     America/New_York  airport
# 3601  -78.732201      728      -5.0   A     America/New_York  airport
# 3629  -76.668297      146      -5.0   A     America/New_York  airport
# 1346    2.550000      392       1.0   E         Europe/Paris  airport
# 3363  -85.203796      683      -5.0   A     America/New_York  airport
# 3780  -78.452904      639      -5.0   A     America/New_York  airport
# 3805  -91.710800      869      -6.0   A      America/Chicago  airport
# 3274  -81.849800      791      -5.0   A     America/New_York  airport
# 3656  -80.943100      748      -5.0   A     America/New_York  airport
# 3541  -82.891899      815      -5.0   A     America/New_York  airport
# 3811  -88.278099      755      -6.0   A      America/Chicago  airport
# 3503  -92.219597      889      -6.0   A      America/Chicago  airport
# 1794  -86.877098       22      -5.0   S       America/Cancun  airport
# 3276  -84.667801      896      -5.0   A     America/New_York  airport
# 3807  -89.666801     1277      -6.0   A      America/Chicago  airport
# 3412  -84.219398     1009      -5.0   A     America/New_York  airport
# 4089  -90.709503     1077      -6.0   A      America/Chicago  airport
# ...          ...      ...       ...  ..                  ...      ...
# 3511 -157.921997       13     -10.0   N     Pacific/Honolulu  airport
# 3498  -77.455803      312      -5.0   A     America/New_York  airport
# 3365  -90.075897      346      -6.0   A      America/Chicago  airport
# 3329  -84.587402      861      -5.0   A     America/New_York  airport
# 3328  -96.759201     1219      -6.0   A      America/Chicago  airport
# 3880  -84.079597      668      -5.0   A     America/New_York  airport
# 3776  -71.435699      266      -5.0   A     America/New_York  airport
# 4420  -86.238197      629      -5.0   A     America/New_York  airport
# 3564  -88.242798      219      -6.0   A      America/Chicago  airport
# 1767 -100.107002     1278      -6.0   S  America/Mexico_City  airport
# 1887  -77.466202       16      -5.0   U       America/Nassau  airport
# 3244 -156.429993       54     -10.0   N     Pacific/Honolulu  airport
# 3396  -76.201202       26      -5.0   A     America/New_York  airport
# 3873  -88.773804      410      -6.0   A      America/Chicago  airport
# 3349  -87.186600      121      -6.0   A      America/Chicago  airport
# 3426  -71.420403       55      -5.0   A     America/New_York  airport
# 3642  -70.309303       76      -5.0   A     America/New_York  airport
# 3843 -103.056999     3204      -7.0   A       America/Denver  airport
# 3781  -79.975403     1175      -5.0   A     America/New_York  airport
# 3398  -81.202103       50      -5.0   A     America/New_York  airport
# 4064  -86.317299      799      -5.0   A     America/New_York  airport
# 4030  -77.848701     1239      -5.0   A     America/New_York  airport
# 1825  -84.208801     3021      -6.0   U   America/Costa_Rica  airport
# 3598 -121.591003       27      -8.0   A  America/Los_Angeles  airport
# 4043  -89.677902      598      -6.0   A      America/Chicago  airport
# 3827  -82.554398       30      -5.0   A     America/New_York  airport
# 3993  -94.059898     1031      -6.0   A      America/Chicago  airport
# 2736  -64.973396       23      -4.0   U    America/St_Thomas  airport
# 2751  -63.108898       13      -4.0   U      America/Curacao  airport
# 164  -106.699997     1653      -6.0   N       America/Regina  airport
#
#            source
# 4392  OurAirports
# 3804  OurAirports
# 3784  OurAirports
# 4384  OurAirports
# 2083  OurAirports
# 3619  OurAirports
# 3467  OurAirports
# 2092  OurAirports
# 3458  OurAirports
# 3801  OurAirports
# 3606  OurAirports
# 3799  OurAirports
# 3475  OurAirports
# 3236  OurAirports
# 3601  OurAirports
# 3629  OurAirports
# 1346  OurAirports
# 3363  OurAirports
# 3780  OurAirports
# 3805  OurAirports
# 3274  OurAirports
# 3656  OurAirports
# 3541  OurAirports
# 3811  OurAirports
# 3503  OurAirports
# 1794  OurAirports
# 3276  OurAirports
# 3807  OurAirports
# 3412  OurAirports
# 4089  OurAirports
# ...           ...
# 3511  OurAirports
# 3498  OurAirports
# 3365  OurAirports
# 3329  OurAirports
# 3328  OurAirports
# 3880  OurAirports
# 3776  OurAirports
# 4420  OurAirports
# 3564  OurAirports
# 1767  OurAirports
# 1887  OurAirports
# 3244  OurAirports
# 3396  OurAirports
# 3873  OurAirports
# 3349  OurAirports
# 3426  OurAirports
# 3642  OurAirports
# 3843  OurAirports
# 3781  OurAirports
# 3398  OurAirports
# 4064  OurAirports
# 4030  OurAirports
# 1825  OurAirports
# 3598  OurAirports
# 4043  OurAirports
# 3827  OurAirports
# 3993  OurAirports
# 2736  OurAirports
# 2751  OurAirports
# 164   OurAirports
#
# [205 rows x 14 columns]

# %%
kentucky2 = list(transfer2)
len(kentucky2)
# Out:
# 1853

# %%
routescombination2 = pd.DataFrame(columns=['id', 'name', 'city', 'country', 'iata', 'icao', 'latitude', 'longitude', 'altitude','timezone', 'dst', 'tz', 'type', 'source'])
for i in range(len(kentucky2)):
    lexingtonroutes = airports[(airports['iata']==str(kentucky2[i]))]
    routescombination2 = routescombination2.append(lexingtonroutes)
routescombination2
# Out:
#         id                                               name  \
# 3467  3682   Hartsfield Jackson Atlanta International Airport
# 3498  3714            Washington Dulles International Airport
# 3658  3878                      Orlando International Airport
# 4739  6130                         Mid Delta Regional Airport
# 3611  3830               Chicago O'Hare International Airport
# 3430  3645          Detroit Metropolitan Wayne County Airport
# 3638  3858  Minneapolis-St Paul International/Wold-Chamber...
# 3656  3876            Charlotte Douglas International Airport
# 3308  3520          Ronald Reagan Washington National Airport
# 3455  3670            Dallas Fort Worth International Airport
# 3402  3617     St Petersburg Clearwater International Airport
# 3913  4167              Orlando Sanford International Airport
# 3533  3751                       Denver International Airport
# 5062  6505                       Phoenix-Mesa-Gateway Airport
# 3657  3877                     McCarran International Airport
# 5301  7056                           Charlotte County Airport
# 3303  3515                 Myrtle Beach International Airport
# 3579  3797               John F Kennedy International Airport
# 3361  3576                        Miami International Airport
# 3534  3752                 Philadelphia International Airport
# 191    193            Lester B. Pearson International Airport
# 1346  1382            Charles de Gaulle International Airport
# 1794  1852                       Cancún International Airport
# 3606  3825                      Bradley International Airport
# 3475  3690                    Nashville International Airport
# 3236  3448  General Edward Lawrence Logan International Ai...
# 3629  3849  Baltimore/Washington International Thurgood Ma...
# 3282  3494               Newark Liberty International Airport
# 3319  3533    Fort Lauderdale Hollywood International Airport
# 3470  3685               Gerald R. Ford International Airport
# ...    ...                                                ...
# 4057  4352                             Norilsk-Alykel Airport
# 4068  4364                               Novy Urengoy Airport
# 4749  6143                                      Nadym Airport
# 4735  6124                                     Beslan Airport
# 2814  2973                            Bolshoye Savino Airport
# 2767  2917                                   Pavlodar Airport
# 6238  8740                              Gorno-Altaysk Airport
# 2815  2974                                     Surgut Airport
# 2788  2942                   Simferopol International Airport
# 2806  2963                     Stavropol Shpakovskoye Airport
# 3867  4111                    Roshchino International Airport
# 4012  4297                                  Bogashevo Airport
# 4699  6086                           Ust-Kamennogorsk Airport
# 6256  8775                       Gabala International Airport
# 6255  8774                     Lankaran International Airport
# 3737  3965                              Gyumri Shirak Airport
# 1505  1546             Federico Fellini International Airport
# 2773  2926                                  Ignatyevo Airport
# 4709  6098                                     Ugolny Airport
# 2776  2930                                      Sokol Airport
# 4744  6138                            Khanty Mansiysk Airport
# 2789  2944                Kiev Zhuliany International Airport
# 4078  4375                                  Sary-Arka Airport
# 4696  6083                                  Kokshetau Airport
# 1542  1584                                  Pardubice Airport
# 2778  2932                                   Yelizovo Airport
# 4794  6189                                   Cam Ranh Airport
# 4069  4365                                   Noyabrsk Airport
# 4743  6137                                  Salekhard Airport
# 5783  7863                                     Belbek Airport
#
#                    city         country iata  icao   latitude   longitude  \
# 3467            Atlanta   United States  ATL  KATL  33.636700  -84.428101
# 3498         Washington   United States  IAD  KIAD  38.944500  -77.455803
# 3658            Orlando   United States  MCO  KMCO  28.429399  -81.308998
# 4739         Greenville   United States  GLH  KGLH  33.482899  -90.985603
# 3611            Chicago   United States  ORD  KORD  41.978600  -87.904800
# 3430            Detroit   United States  DTW  KDTW  42.212399  -83.353401
# 3638        Minneapolis   United States  MSP  KMSP  44.882000  -93.221802
# 3656          Charlotte   United States  CLT  KCLT  35.214001  -80.943100
# 3308         Washington   United States  DCA  KDCA  38.852100  -77.037697
# 3455  Dallas-Fort Worth   United States  DFW  KDFW  32.896801  -97.038002
# 3402     St. Petersburg   United States  PIE  KPIE  27.910200  -82.687401
# 3913            Sanford   United States  SFB  KSFB  28.777599  -81.237503
# 3533             Denver   United States  DEN  KDEN  39.861698 -104.672997
# 5062               Mesa   United States  AZA  KIWA  33.307800 -111.654999
# 3657          Las Vegas   United States  LAS  KLAS  36.080101 -115.152000
# 5301        Punta Gorda   United States  PGD  KPGD  26.920200  -81.990501
# 3303       Myrtle Beach   United States  MYR  KMYR  33.679699  -78.928299
# 3579           New York   United States  JFK  KJFK  40.639801  -73.778900
# 3361              Miami   United States  MIA  KMIA  25.793200  -80.290604
# 3534       Philadelphia   United States  PHL  KPHL  39.871899  -75.241096
# 191             Toronto          Canada  YYZ  CYYZ  43.677200  -79.630600
# 1346              Paris          France  CDG  LFPG  49.012798    2.550000
# 1794             Cancun          Mexico  CUN  MMUN  21.036501  -86.877098
# 3606      Windsor Locks   United States  BDL  KBDL  41.938900  -72.683197
# 3475          Nashville   United States  BNA  KBNA  36.124500  -86.678200
# 3236             Boston   United States  BOS  KBOS  42.364300  -71.005203
# 3629          Baltimore   United States  BWI  KBWI  39.175400  -76.668297
# 3282             Newark   United States  EWR  KEWR  40.692501  -74.168701
# 3319    Fort Lauderdale   United States  FLL  KFLL  26.072599  -80.152702
# 3470       Grand Rapids   United States  GRR  KGRR  42.880798  -85.522797
# ...                 ...             ...  ...   ...        ...         ...
# 4057            Norilsk          Russia  NSK  UOOO  69.311096   87.332199
# 4068       Novy Urengoy          Russia  NUX  USMU  66.069397   76.520302
# 4749              Nadym          Russia  NYM  USMM  65.480904   72.698898
# 4735             Beslan          Russia  OGZ  URMO  43.205101   44.606602
# 2814               Perm          Russia  PEE  USPP  57.914501   56.021198
# 2767           Pavlodar      Kazakhstan  PWQ  UASP  52.195000   77.073898
# 6238      Gorno-Altaysk          Russia  RGK  UNBG  51.966702   85.833298
# 2815             Surgut          Russia  SGC  USRR  61.343700   73.401802
# 2788         Simferopol         Ukraine  SIP  UKFF  45.052200   33.975101
# 2806          Stavropol          Russia  STW  URMT  45.109200   42.112801
# 3867             Tyumen          Russia  TJM  USTR  57.189602   65.324303
# 4012              Tomsk          Russia  TOF  UNTT  56.380299   85.208298
# 4699    Ust Kamenogorsk      Kazakhstan  UKK  UASK  50.036598   82.494202
# 6256             Qabala      Azerbaijan  GBB  UBBQ  40.826667   47.712500
# 6255           Lankaran      Azerbaijan  LLK  UBBL  38.746399   48.818001
# 3737             Gyumri         Armenia  LWN  UDSG  40.750401   43.859299
# 1505             Rimini           Italy  RMI  LIPR  44.020302   12.611700
# 2773     Blagoveschensk          Russia  BQS  UHBB  50.425400  127.412003
# 4709             Anadyr          Russia  DYR  UHMA  64.734901  177.740997
# 2776            Magadan          Russia  GDX  UHMM  59.910999  150.720001
# 4744    Khanty-Mansiysk          Russia  HMA  USHH  61.028500   69.086098
# 2789               Kiev         Ukraine  IEV  UKKK  50.401940   30.451940
# 4078          Karaganda      Kazakhstan  KGF  UAKK  49.670799   73.334396
# 4696          Kokshetau      Kazakhstan  KOV  UACK  53.329102   69.594597
# 1542          Pardubice  Czech Republic  PED  LKPD  50.013401   15.738600
# 2778      Petropavlovsk          Russia  PKC  UHPP  53.167900  158.453995
# 4794          Nha Trang         Vietnam  CXR  VVCR  11.998200  109.219002
# 4069           Noyabrsk          Russia  NOJ  USRO  63.183300   75.269997
# 4743          Salekhard          Russia  SLY  USDD  66.590797   66.611000
# 5783         Sevastopol         Ukraine  UKS  UKFB  44.688999   33.570999
#
#      altitude  timezone dst                   tz     type       source
# 3467     1026      -5.0   A     America/New_York  airport  OurAirports
# 3498      312      -5.0   A     America/New_York  airport  OurAirports
# 3658       96      -5.0   A     America/New_York  airport  OurAirports
# 4739      131      -6.0   A      America/Chicago  airport  OurAirports
# 3611      672      -6.0   A      America/Chicago  airport  OurAirports
# 3430      645      -5.0   A     America/New_York  airport  OurAirports
# 3638      841      -6.0   A      America/Chicago  airport  OurAirports
# 3656      748      -5.0   A     America/New_York  airport  OurAirports
# 3308       15      -5.0   A     America/New_York  airport  OurAirports
# 3455      607      -6.0   A      America/Chicago  airport  OurAirports
# 3402       11      -5.0   A     America/New_York  airport  OurAirports
# 3913       55      -5.0   A     America/New_York  airport  OurAirports
# 3533     5431      -7.0   A       America/Denver  airport  OurAirports
# 5062     1382      -7.0   N      America/Phoenix  airport  OurAirports
# 3657     2181      -8.0   A  America/Los_Angeles  airport  OurAirports
# 5301       26      -5.0   A     America/New_York  airport  OurAirports
# 3303       25      -5.0   A     America/New_York  airport  OurAirports
# 3579       13      -5.0   A     America/New_York  airport  OurAirports
# 3361        8      -5.0   A     America/New_York  airport  OurAirports
# 3534       36      -5.0   A     America/New_York  airport  OurAirports
# 191       569      -5.0   A      America/Toronto  airport  OurAirports
# 1346      392       1.0   E         Europe/Paris  airport  OurAirports
# 1794       22      -5.0   S       America/Cancun  airport  OurAirports
# 3606      173      -5.0   A     America/New_York  airport  OurAirports
# 3475      599      -6.0   A      America/Chicago  airport  OurAirports
# 3236       20      -5.0   A     America/New_York  airport  OurAirports
# 3629      146      -5.0   A     America/New_York  airport  OurAirports
# 3282       18      -5.0   A     America/New_York  airport  OurAirports
# 3319        9      -5.0   A     America/New_York  airport  OurAirports
# 3470      794      -5.0   A     America/New_York  airport  OurAirports
# ...       ...       ...  ..                  ...      ...          ...
# 4057      574       7.0   N     Asia/Krasnoyarsk  airport  OurAirports
# 4068      210       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 4749       49       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 4735     1673       3.0   N        Europe/Moscow  airport  OurAirports
# 2814      404       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 2767      410       6.0   U       Asia/Qyzylorda  airport  OurAirports
# 6238      965       7.0   N     Asia/Krasnoyarsk  airport  OurAirports
# 2815      200       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 2788      639       3.0   E    Europe/Simferopol  airport  OurAirports
# 2806     1486       3.0   N        Europe/Moscow  airport  OurAirports
# 3867      378       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 4012      597       7.0   N     Asia/Krasnoyarsk  airport  OurAirports
# 4699      939       6.0   U       Asia/Qyzylorda  airport  OurAirports
# 6256      935       4.0   E            Asia/Baku  airport  OurAirports
# 6255       30       4.0   U            Asia/Baku  airport  OurAirports
# 3737     5000       4.0   E         Asia/Yerevan  airport  OurAirports
# 1505       40       1.0   E          Europe/Rome  airport  OurAirports
# 2773      638       9.0   N         Asia/Yakutsk  airport  OurAirports
# 4709      194      12.0   N          Asia/Anadyr  airport  OurAirports
# 2776      574      11.0   N   Asia/Srednekolymsk  airport  OurAirports
# 4744       76       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 2789      587       2.0   E          Europe/Kiev  airport  OurAirports
# 4078     1765       6.0   U       Asia/Qyzylorda  airport  OurAirports
# 4696      900       6.0   U       Asia/Qyzylorda  airport  OurAirports
# 1542      741       1.0   E        Europe/Prague  airport  OurAirports
# 2778      131      12.0   N          Asia/Anadyr  airport  OurAirports
# 4794       40       7.0   U          Asia/Saigon  airport  OurAirports
# 4069      446       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 4743      218       5.0   N   Asia/Yekaterinburg  airport  OurAirports
# 5783      344       3.0   U    Europe/Simferopol  airport  OurAirports
#
# [1808 rows x 14 columns]

# %%
geography = routecombination['latitude'].mean(), routecombination['longitude'].mean()

# %%
geolist = routecombination[["latitude","longitude"]].values.tolist()
labels = routecombination["city"].values.tolist()

lextransfer1 = folium.Map(location=location, zoom_start=3)
for point in range(len(locationlist)):
    popup = folium.Popup(labels[point], parse_html=True)
    folium.Marker(geolist[point], popup=popup).add_to(lextransfer1)

lextransfer1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-81e878a09d4d> in <module>()
#       4 lextransfer1 = folium.Map(location=location, zoom_start=3)
#       5 for point in range(len(locationlist)):
# ----> 6     popup = folium.Popup(labels[point], parse_html=True)
#       7     folium.Marker(geolist[point], popup=popup).add_to(lextransfer1)
#       8
#
# IndexError: list index out of range

# %%
lextransfer1.save("lextransfer1.html")

# %%
geography2 = routescombination2['latitude'].mean(), routescombination2['longitude'].mean()

# %%
geolist2 = routescombination2[["latitude","longitude"]].values.tolist()
labels = routescombination2["city"].values.tolist()

lex_air_2_transfers = folium.Map(location=geography2, zoom_start=2)
for point in range(len(geolist2)):
    popup = folium.Popup(labels[point], parse_html=True)
    folium.Marker(geolist2[point], popup=popup).add_to(lextransfer2)

lextransfer2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-77e3a99b5903> in <module>()
#       5 for point in range(len(geolist2)):
#       6     popup = folium.Popup(labels[point], parse_html=True)
# ----> 7     folium.Marker(geolist2[point], popup=popup).add_to(lextransfer2)
#       8
#       9 lextransfer2
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\branca\element.py in add_to(self, parent, name, index)
#     107     def add_to(self, parent, name=None, index=None):
#     108         """Add element to a parent."""
# --> 109         parent.add_child(self, name=name, index=index)
#     110         return self
#     111
#
# AttributeError: 'tuple' object has no attribute 'add_child'

# %%
lextransfer2.save("lextransfer2.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-cb5a7a324ed2> in <module>()
# ----> 1 lextransfer2.save("lextransfer2.html")
#
# AttributeError: 'tuple' object has no attribute 'save'
